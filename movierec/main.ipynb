# %% [markdown]
# MOVIES RECOMMENDATION SYSTEM

# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv('dataset.csv')
movies = movies.copy()

# %%
movies.head(5)
# Out:
#       id                        title                 genre original_language  \
# 0    278     The Shawshank Redemption           Drama,Crime                en
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance                hi
# 2    238                The Godfather           Drama,Crime                en
# 3    424             Schindler's List     Drama,History,War                en
# 4    240       The Godfather: Part II           Drama,Crime                en
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...      94.075   1994-09-23
# 1  Raj is a rich, carefree, happy-go-lucky second...      25.408   1995-10-19
# 2  Spanning the years 1945 to 1955, a chronicle o...      90.585   1972-03-14
# 3  The true story of how businessman Oskar Schind...      44.761   1993-12-15
# 4  In the continuing saga of the Corleone crime f...      57.749   1974-12-20
#
#    vote_average  vote_count
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...

# %%
movies['tags']=movies['overview']+movies['genre']
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...

# %%
movies=movies.drop(columns=['original_language','popularity','release_date','vote_average','vote_count'])
movies
# Out:
#           Id                                  title  \
# 0        278               The Shawshank Redemption
# 1      19404            Dilwale Dulhania Le Jayenge
# 2        238                          The Godfather
# 3        424                       Schindler's List
# 4        240                 The Godfather: Part II
# ...      ...                                    ...
# 8994   10327  Legally Blonde 2: Red, White & Blonde
# 8995  300467                     Dark Was the Night
# 8996  605286                 Si vive una volta sola
# 8997  449459                          The Vanishing
# 8998  429471                          Captive State
#
#                                                     Tag
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# ...

# %%
column_renamed={'id':'Id','original_title':'Title','tags':'Tag'}
movies.rename(columns=column_renamed,inplace=True)
movies.to_csv('Dataset_Tmdb.csv', index=False, mode='w')
movies
# Out:
#           Id                                  title  \
# 0        278               The Shawshank Redemption
# 1      19404            Dilwale Dulhania Le Jayenge
# 2        238                          The Godfather
# 3        424                       Schindler's List
# 4        240                 The Godfather: Part II
# ...      ...                                    ...
# 8994   10327  Legally Blonde 2: Red, White & Blonde
# 8995  300467                     Dark Was the Night
# 8996  605286                 Si vive una volta sola
# 8997  449459                          The Vanishing
# 8998  429471                          Captive State
#
#                                                     Tag
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# ...

# %%
movies = movies.drop(movies.index[-865:])

# %%
movies = movies.drop(movies.index[-135:])
movies
# Out:
#           Id                                  title  \
# 0        278               The Shawshank Redemption
# 1      19404            Dilwale Dulhania Le Jayenge
# 2        238                          The Godfather
# 3        424                       Schindler's List
# 4        240                 The Godfather: Part II
# ...      ...                                    ...
# 7994  491473                            Gloria Bell
# 7995  257440                              Term Life
# 7996  199661                              Josephine
# 7997   73937                           The Big Year
# 7998    8698  The League of Extraordinary Gentlemen
#
#                                                     Tag
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# ...

# %%
movies = movies.drop(movies.index[-1:])
movies
# Out:
#           Id                        title  \
# 0        278     The Shawshank Redemption
# 1      19404  Dilwale Dulhania Le Jayenge
# 2        238                The Godfather
# 3        424             Schindler's List
# 4        240       The Godfather: Part II
# ...      ...                          ...
# 7993   10678      Bringing Down the House
# 7994  491473                  Gloria Bell
# 7995  257440                    Term Life
# 7996  199661                    Josephine
# 7997   73937                 The Big Year
#
#                                                     Tag
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 7993  When a lonely guy meets a woman on the interne...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=9000,stop_words='english')

# %%
vector=cv.fit_transform(movies['Tag'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (7998, 9000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.0571662 , 0.13076645, ..., 0.        , 0.03363364,
#         0.        ],
#        [0.0571662 , 1.        , 0.07624929, ..., 0.06108472, 0.09805807,
#         0.0347524 ],
#        [0.13076645, 0.07624929, 1.        , ..., 0.01863067, 0.02990743,
#         0.        ],
#        ...,
#        [0.        , 0.06108472, 0.01863067, ..., 1.        , 0.0239594 ,
#         0.        ],
#        [0.03363364, 0.09805807, 0.02990743, ..., 0.0239594 , 1.        ,
#         0.04089304],
#        [0.        , 0.0347524 , 0.        , ..., 0.        , 0.04089304,
#         1.        ]])

# %%
def recommend(movie_title):
    index= movies[movies['title']==movie_title].index[0]
    distance=sorted(list(enumerate(similarity[index])),reverse=True,key=lambda vector:vector[1])
    for i in distance[0:11]:
        print(movies.iloc[i[0]].title)

# %%
recommendations = recommend('Iron Man')
print(recommendations)
# Out:
# Iron Man
# Iron Man 3
# Guardians of the Galaxy Vol. 2
# Avengers: Age of Ultron
# Star Wars: Episode III - Revenge of the Sith
# G.O.R.A.
# Iron Man 2
# Charlie's Angels
# Everything Everywhere All at Once
# Star Wars: Episode I - The Phantom Menace
# The Rocketeer
# None

# %%
import pickle

# %%
pickle.dump(movies,open('movies_lst.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
pickle.load(open('movies_lst.pkl','rb'))
# Out:
#           Id                        title  \
# 0        278     The Shawshank Redemption
# 1      19404  Dilwale Dulhania Le Jayenge
# 2        238                The Godfather
# 3        424             Schindler's List
# 4        240       The Godfather: Part II
# ...      ...                          ...
# 7993   10678      Bringing Down the House
# 7994  491473                  Gloria Bell
# 7995  257440                    Term Life
# 7996  199661                    Josephine
# 7997   73937                 The Big Year
#
#                                                     Tag
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 7993  When a lonely guy meets a woman on the interne...
# ...
